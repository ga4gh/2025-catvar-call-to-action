# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from matplotlib import ticker

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.rcParams["font.family"] = "arial"

def normalize_rgb(dictionary):
    for color in dictionary.keys():
        r, g, b = dictionary[color]
        dictionary[color] = (r / 255., g / 255., b / 255.)
    return dictionary

tableau10 = {
    'blue': (78, 121, 167), 'orange': (242, 142, 43), 'red': (225, 87, 89),
    'cyan': (118, 183, 178), 'green': (89, 161, 79), 'yellow': (237, 201, 72),
    'purple': (176, 122, 161), 'pink': (225, 157, 167), 'brown': (156, 117, 95),
    'grey': (186, 176, 172), 'white': (240, 240, 240)
}

tableau10 = normalize_rgb(tableau10)

def remove_spines(ax):
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    return ax

# %%
file = 'hgvs4variation.txt'
with open(file, 'r') as f:
    last_comment = None
    for line in f:
        if line.startswith('#'):
            last_comment = line
        else:
            break  # stop once the actual data begins

columns = last_comment.lstrip("#").strip().split("\t")

df = pd.read_csv(
    "hgvs4variation.txt",
    sep="\t",
    comment="#",
    names=columns,
    header=None,
    low_memory=False
    #nrows=10,
    #usecols=['VariationID', 'AlleleID', 'NucleotideExpression', 'ProteinExpression', 'Assembly']
)

df.head()
# Out:
#   Symbol GeneID  VariationID  AlleleID     Type Assembly  \
# 0      -      -           25     15064  genomic   GRCh38
# 1      -      -           25     15064  genomic   GRCh38
# 2      -      -           25     15064  genomic   GRCh37
# 3      -      -           25     15064  genomic   GRCh37
# 4      -      -          116     15155  genomic   GRCh37
#
#                             NucleotideExpression  \
# 0  NC_000020.11:g.25383511_25397601del14091insGG
# 1        NC_000020.11:g.25383511_25397600delinsG
# 2       NC_000020.10:g.25364147_25378237delinsGG
# 3  NC_000020.10:g.25364147_25378237del14091insGG
# 4                     NC_000013.10:g.29233226del
#
#                    NucleotideChange ProteinExpression ProteinChange  \
# 0  g.25383511_25397601del14091insGG                 -             -
# 1        g.25383511_25397600delinsG                 -             -
# 2       g.25364147_25378237delinsGG                 -             -
# 3  g.25364147_25378237del14091insGG                 -             -
# 4                     g.29233226del                 -             -
#
#   UsedForNaming Submitted OnRefSeqGene
# 0            No        No           No
# 1            No        No           No
# 2            No        No           No
# 3            No        No           No
# 4            No   Current           No

# %%
a = df[df['VariationID'].eq(15333)]

# %%
a[a['UsedForNaming'].eq('Yes')]
# Out:
#          Symbol GeneID  VariationID  AlleleID     Type Assembly  \
# 17692939    HBB   3043        15333     30372  genomic       na
# 17692942    HBB   3043        15333     30372  genomic       na
# 17692944    HBB   3043        15333     30372  genomic       na
# 17692945    HBB   3043        15333     30372  genomic       na
# 17692946    HBB   3043        15333     30372   coding       na
# 17692947    HBB   3043        15333     30372  genomic   GRCh38
# 17692948    HBB   3043        15333     30372  genomic   GRCh37
# 17702761    HBD   3045        15333     30372  genomic       na
#
#                NucleotideExpression NucleotideChange      ProteinExpression  \
# 17692939         LRG_1232:g.5070A>T                -                      -
# 17692942       NG_042296.1:g.533T>A         g.533T>A                      -
# 17692944      NG_046672.1:g.4937T>A        g.4937T>A                      -
# 17692945      NG_059281.1:g.5070A>T        g.5070A>T                      -
# 17692946        NM_000518.5:c.20A>T          c.20A>T  NP_000509.1:p.Glu7Val
# 17692947  NC_000011.10:g.5227002T>A     g.5227002T>A                      -
# 17692948   NC_000011.9:g.5248232T>A     g.5248232T>A                      -
# 17702761     NG_000007.3:g.70614A>T       g.70614A>T                      -
#
#          ProteinChange UsedForNaming Submitted OnRefSeqGene
# 17692939             -           Yes        No          Yes
# 17692942             -           Yes        No           No
# 17692944             -           Yes        No           No
# 17692945             -           Yes        No          Yes
# 17692946     p.Glu7Val           Yes   Current           No
# 17692947             -           Yes   Current           No
# 17692948             -           Yes   Current           No
# 17702761             -           Yes        No          Yes
